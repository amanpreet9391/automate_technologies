# %%
def menu():
    y=0
    flag=True
    flag1=True
    import socket
    import pyttsx3
    import speech_recognition as sr
    import socket
    s=socket.socket()
    engine= pyttsx3.init()
    mic=sr.Microphone()
    rec=sr.Recognizer()
    s=socket.socket()
    s.connect(("192.168.43.77",12345))
    ch=s.recv(1024)
    option=ch.decode()
    print(option)
    engine.say(option)
    engine.runAndWait()
    option=input()
    with mic as source:
        print("say ...")
        audio=rec.listen(source)
        option=rec.recognize_google(audio)
      #  option=input()
    option=option.encode()
    s.send(option)
    option=option.decode()
    print(option)
    if(option=='local'):
        while(flag):
            print(type(y))
            print("while")
            ch=s.recv(1024)
            ch1=ch.decode()
            print("client:- "+ch1)
            engine.say(ch1)
            engine.runAndWait()
            x=input()
            #with mic as source:
            #    print("say ...")
            #    audio=rec.listen(source)
            #    x=rec.recognize_google(audio)
            x=x.encode()
            s.send(x)
            if x==0:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
            elif x==1:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
                name=input()
                #with mic as source:
                #   print("say ...")
                #    audio=rec.listen(source)
                #    y=rec.recognize_google(audio)
                name=name.encode()
                s.send(name)
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
            elif x==2:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
                name=input()
                #with mic as source:
                #   print("say ...")
                #    audio=rec.listen(source)
                #    y=rec.recognize_google(audio)
                name=name.encode()
                s.send(name)
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
            elif x==3:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
                file=input()
                #with mic as source:
                #   print("say ...")
                #    audio=rec.listen(source)
                #    y=rec.recognize_google(audio)
                file=file.encode()
                s.send(file)
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
            elif x==4:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
            elif x==5:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
            elif x==6:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
                y=int(input())
                print(type(y))
                #with mic as source:
                #   print("say ...")
                #    audio=rec.listen(source)
                #   y=rec.recognize_google(audio)
                y=y.encode()
                s.send(y)
                if y==1:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                    slave_ip=input()
                    slave_ip=slave_ip.encode()
                    s.send(slave_ip)
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                elif y==2:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                    master_ip=input()
                    master_ip=master_ip.encode()
                    s.send(master_ip)
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                elif y==3:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                    slave_ip=input()
                    slave_ip=slave_ip.encode()
                    s.send(slave_ip)
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                else:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
            elif x==7:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
                z=int(input())
                print(type(y))
                #with mic as source:
                #   print("say ...")
                #    audio=rec.listen(source)
                #    y=rec.recognize_google(audio)
                z=z.encode()
                s.send(z)
                if z==1:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                    jobtracker_ip=input()
                    jobtracker_ip=jobtracker_ip.encode()
                    s.send(jobtracker_ip)
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                elif z==2:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                    tasktracker_ip=input()
                    tasktracker_ip=tasktracker_ip.encode()
                    s.send(tasktracker_ip)
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                elif z==3:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                    client_ip=input()
                    client_ip=client_ip.encode()
                    s.send(client_ip)
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                else:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
            elif x==8:
                flag=False
                break
    elif(option=='remote'):
        print("while")
        ch=s.recv(1024)
        ch1=ch.decode()
        print("client:- "+ch1)
        engine.say(ch1)
        engine.runAndWait()
        ip=input("Enter remote IP")
        ip=ip.encode()
        s.send(ip )
        while(flag1):
            ch=s.recv(1024)
            ch1=ch.decode()
            print("client:- "+ch1)
            engine.say(ch1)
            engine.runAndWait()
            inp=input()
            #with mic as source:
            #        print("say ...")
            #        audio=rec.listen(source)
            #        inp=rec.recognize_google(audio)
            x=inp.encode()
            s.send(x)
            if x==0:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
            elif x==1:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
                inp=input()
                #with mic as source:
                #   print("say ...")
                #    audio=rec.listen(source)
                #    y=rec.recognize_google(audio)
                inp1=inp.encode()
                s.send(inp1)
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
            elif x==2:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
                inp=input()
                #with mic as source:
                #   print("say ...")
                #    audio=rec.listen(source)
                #    y=rec.recognize_google(audio)
                inp1=inp.encode()
                s.send(inp1)
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()

            elif x==3:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
                inp=input()
                #with mic as source:
                #   print("say ...")
                #    audio=rec.listen(source)
                #    y=rec.recognize_google(audio)
                inp1=inp.encode()
                s.send(inp1)
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()

            elif x==4:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
            elif x==5:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
            elif x==6:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
                y=input()
                #with mic as source:
                #    print("say ...")
                #    audio=rec.listen(source)
                #    y=rec.recognize_google(audio)
                y=y.encode()
                s.send(y)
                if y==1:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                    slave_ip=input()
                    slave_ip=slave_ip.encode()
                    s.send(slave_ip)
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                elif y==2:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                    master_ip=input()
                    master_ip=master_ip.encode()
                    s.send(master_ip)
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                elif y==3:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                    slave_ip=input()
                    slave_ip=slave_ip.encode()
                    s.send(slave_ip)
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                else:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
            elif x==7:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
                z=int(input())
                #with mic as source:
                #    print("say ...")
                #    audio=rec.listen(source)
                #    y=rec.recognize_google(audio)
                z=z.encode()
                s.send(z)
                if z==1:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                    jobtracker_ip=input()
                    jobtracker_ip=jobtracker_ip.encode()
                    s.send(jobtracker_ip)
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                elif z==2:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                    tasktracker_ip=input()
                    tasktracker_ip=tasktracker_ip.encode()
                    s.send(tasktracker_ip)
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                elif z==3:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                    client_ip=input()
                    client_ip=client_ip.encode()
                    s.send(client_ip)
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
                else:
                    ch=s.recv(1024)
                    ch1=ch.decode()
                    print("client:- "+ch1)
                    engine.say(ch1)
                    engine.runAndWait()
            elif x==8:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
            elif x==9:
                ch=s.recv(1024)
                ch1=ch.decode()
                print("client:- "+ch1)
                engine.say(ch1)
                engine.runAndWait()
            elif x==10:
                flag1=False
                break

# %%
import pyttsx3
import speech_recognition as sr
import webbrowser as wb
speaker = pyttsx3.init()
speaker.say("Welcome . What do you want to do?")
speaker.runAndWait()

# %%
mic = sr.Microphone()
r = sr.Recognizer()
a=0

with mic as source:
    print("say :")
 #   audio = r.listen(source)
 #   text = r.recognize_google(audio)
    text=input()
while a == 0:
        if "don't" in text:
                print("okay. what do you want to do then")
                speaker.say("okay. what do you want to do then")
                speaker.runAndWait()
                print("say :")
                audio = r.listen(source)
                text = r.recognize_google(audio)
                print(text)
                a=0

        else:

                if "menu" in text:
                    #print("Okay . I am redirecting you to the menu page")
                    speaker.say("Okay . I am redirecting you to the menu")
                    speaker.runAndWait()
                    menu()
                    #wb.open_new_tab("file:///C:/Users//Desktop/PROJECT/menu/new4.html")
                     ## wb.open_new_tab('http://172.20.10.6/men1.html')
                    

                #elif "project" in text:
                        #print("okay. i am redirecting you to your project")
                        #speaker.say("okay. i am redirecting you to your project")
                        #speaker.runAndWait()
                                 ## wb.open_new_tab("file:///C:/Users//Desktop/PROJECT/project/main.html")
                        #wb.open_new_tab('http://localhost:8888/notebooks/Desktop/project_lw/crime-jaipur.ipynb')

                                ##  webbrowser.open('http://localhost:8888/notebooks/Desktop/project_lw/tts%20.ipynb') 
                        #a=1
# Out:
# say :
# project
# okay. i am redirecting you to your project

# %%
menu()
